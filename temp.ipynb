# %%
a = 'abc'
b = 'a'
c = 'abc'

# %%
assert all([a,b,c]), 'Error need all value'

# %%
# %pip install langchain_text_splitters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: C:\Users\Yajith\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from knowledge_store.vector_store import ChromaVectorStore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from knowledge_store.vector_store import ChromaVectorStore
#
# ModuleNotFoundError: No module named 'knowledge_store'
